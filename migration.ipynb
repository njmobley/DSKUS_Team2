# %%
import pandas as pd

# %%
migration_data = pd.read_csv("migration data.csv")

# %%
migration_data
# Out:
#     Index Region, development group, country or area  Location code  \
# 0     102                         South-Eastern Asia            920
# 1     103                          Brunei Darussalam             96
# 2     104                                   Cambodia            116
# 3     105                                  Indonesia            360
# 4     106           Lao People's Democratic Republic            418
# 5     107                                  Malaysia*            458
# 6     108                                    Myanmar            104
# 7     109                                Philippines            608
# 8     110                                  Singapore            702
# 9     111                                   Thailand            764
# 10    112                                Timor-Leste            626
# 11    113                                   Viet Nam            704
#
#          1990       1995        2000        2005        2010        2015  \
# 0   7 725 395  9 694 248  12 088 166  14 537 009  18 113 912  20 787 865
# 1      26 323     35 052      45 242      45 314      44 541      45 110
# 2     355 428    418 213     459 621     674 436     953 059   1 074 572
# 3   1 622 259  1 937 233   2 415 077   2 781 287   3 415 963   4 065 095
# 4     483 008    547 786     649 287     897 002   1 198 862   1 288 179
# 5     560 353    861 208   1 201 135   1 379 305   1 599 061   1 781 038
# 6     685 308    911 445   1 224 310   1 736 590   2 492 274   2 842 494
# 7   2 012 499  2 481 963   3 062 665   3 684 528   4 692 695   5 498 232
# 8     156 444    168 100     192 930     235 683     282 421     324 639
# 9     306 924    411 878     531 028     631 678     769 257     921 690
# 10     11 261     79 050     148 339      94 961      35 037      37 325
# 11  1 505 588  1 842 320   2 158 532   2 376 225   2 630 742   2 909 491
#
#           2020
# 0   23 580 736
# 1       45 340
# 2    1 104 819
# 3    4 601 369
# 4    1 296 051
# 5    1 860 037
# 6    3 711 751
# 7    6 094 307
# 8      348 464
# 9    1 086 985
# 10      39 588
# 11   3 392 025

# %%
df_obj = migration_data.select_dtypes(['object'])
df_obj = df_obj.iloc[:,1:]

# %%
migration_data[df_obj.columns] = df_obj.apply(lambda x : x.str.replace(" ",""))

# %%
for i in range(1990,2021,5):
    migration_data[str(i)] = pd.to_numeric(migration_data[str(i)])

# %%
migration_data
# Out:
#     Index Region, development group, country or area  Location code     1990  \
# 0     102                         South-Eastern Asia            920  7725395
# 1     103                          Brunei Darussalam             96    26323
# 2     104                                   Cambodia            116   355428
# 3     105                                  Indonesia            360  1622259
# 4     106           Lao People's Democratic Republic            418   483008
# 5     107                                  Malaysia*            458   560353
# 6     108                                    Myanmar            104   685308
# 7     109                                Philippines            608  2012499
# 8     110                                  Singapore            702   156444
# 9     111                                   Thailand            764   306924
# 10    112                                Timor-Leste            626    11261
# 11    113                                   Viet Nam            704  1505588
#
#        1995      2000      2005      2010      2015      2020
# 0   9694248  12088166  14537009  18113912  20787865  23580736
# 1     35052     45242     45314     44541     45110     45340
# 2    418213    459621    674436    953059   1074572   1104819
# 3   1937233   2415077   2781287   3415963   4065095   4601369
# 4    547786    649287    897002   1198862   1288179   1296051
# 5    861208   1201135   1379305   1599061   1781038   1860037
# 6    911445   1224310   1736590   2492274   2842494   3711751
# 7   2481963   3062665   3684528   4692695   5498232   6094307
# 8    168100    192930    235683    282421    324639    348464
# 9    411878    531028    631678    769257    921690   1086985
# 10    79050    148339     94961     35037     37325     39588
# 11  1842320   2158532   2376225   2630742   2909491   3392025

# %%
migration_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Index                                       12 non-null     int64
#  1   Region, development group, country or area  12 non-null     object
#  2   Location code                               12 non-null     int64
#  3   1990                                        12 non-null     int64
#  4   1995                                        12 non-null     int64
#  5   2000                                        12 non-null     int64
#  6   2005                                        12 non-null     int64
#  7   2010                                        12 non-null     int64
#  8   2015                                        12 non-null     int64
#  9   2020                                        12 non-null     int64
# dtypes: int64(9), object(1)
# memory usage: 976.0+ bytes

# %%
for i in range(1990,2020) :
    if i not in pd.to_numeric(df_obj.columns) :
        migration_data[str(i)] = 0

# %%
column_names = list(migration_data.columns[:3]) + sorted(migration_data.columns[3:])

# %%
migration_data = migration_data.reindex(columns = column_names)

# %%
for i in range(1990,2016,5):
    for j in range(len(migration_data)):
        y1 = migration_data[str(i)][j]
        y2 = migration_data[str(i+5)][j]
        
        for k in range(4):
            migration_data[str(i+k+1)][j] = y1 + (y2 - y1) / 5 * (k+1)
# Out:
# <ipython-input-99-946daa8f4840>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   migration_data[str(i+k+1)][j] = y1 + (y2 - y1) / 5 * (k+1)

# %%
migration_data
# Out:
#     Index Region, development group, country or area  Location code     1990  \
# 0     102                         South-Eastern Asia            920  7725395
# 1     103                          Brunei Darussalam             96    26323
# 2     104                                   Cambodia            116   355428
# 3     105                                  Indonesia            360  1622259
# 4     106           Lao People's Democratic Republic            418   483008
# 5     107                                  Malaysia*            458   560353
# 6     108                                    Myanmar            104   685308
# 7     109                                Philippines            608  2012499
# 8     110                                  Singapore            702   156444
# 9     111                                   Thailand            764   306924
# 10    112                                Timor-Leste            626    11261
# 11    113                                   Viet Nam            704  1505588
#
#        1991     1992     1993     1994     1995      1996  ...      2011  \
# 0   8119165  8512936  8906706  9300477  9694248  10173031  ...  18648702
# 1     28068    29814    31560    33306    35052     37090  ...     44654
# 2    367985   380542   393099   405656   418213    426494  ...    977361
# 3   1685253  1748248  1811243  1874238  1937233   2032801  ...   3545789
# 4    495963   508919   521874   534830   547786    568086  ...   1216725
# 5    620524   680695   740866   801037   861208    929193  ...   1635456
# 6    730535   775762   820990   866217   911445    974018  ...   2562318
# 7   2106391  2200284  2294177  2388070  2481963   2598103  ...   4853802
# 8    158775   161106   163437   165768   168100    173066  ...    290864
# 9    327914   348905   369896   390887   411878    435708  ...    799743
# 10    24818    38376    51934    65492    79050     92907  ...     35494
# 11  1572934  1640280  1707627  1774973  1842320   1905562  ...   2686491
#
#         2012      2013      2014      2015      2016      2017      2018  \
# 0   19183493  19718283  20253074  20787865  21346439  21905013  22463587
# 1      44768     44882     44996     45110     45156     45202     45248
# 2    1001664   1025966   1050269   1074572   1080621   1086670   1092720
# 3    3675615   3805442   3935268   4065095   4172349   4279604   4386859
# 4    1234588   1252452   1270315   1288179   1289753   1291327   1292902
# 5    1671851   1708247   1744642   1781038   1796837   1812637   1828437
# 6    2632362   2702406   2772450   2842494   3016345   3190196   3364048
# 7    5014909   5176017   5337124   5498232   5617447   5736662   5855877
# 8     299308    307751    316195    324639    329404    334169    338934
# 9     830230    860716    891203    921690    954749    987808   1020867
# 10     35952     36409     36867     37325     37777     38230     38682
# 11   2742241   2797991   2853741   2909491   3005997   3102504   3199011
#
#         2019      2020
# 0   23022161  23580736
# 1      45294     45340
# 2    1098769   1104819
# 3    4494114   4601369
# 4    1294476   1296051
# 5    1844237   1860037
# 6    3537899   3711751
# 7    5975092   6094307
# 8     343699    348464
# 9    1053926   1086985
# 10     39135     39588
# 11   3295518   3392025
#
# [12 rows x 34 columns]
